# %%
X = int(input())
Y = int(input())
print(X+Y)
print(Y-X)
print(X*Y)
# Out:
#  5
#  10
# 15
# 5
# 50

# %%
#F
N,M = map(int, input().split())
X = N%10
Y = M%10
print(f'{X+Y}')
# Out:
#  13 12
# 5

# %%
#G
N = int(input())
X = N*(N+1)//2
print(X)
# Out:
#  3
# 6
