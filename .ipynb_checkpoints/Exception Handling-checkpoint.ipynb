# %% [markdown]
# - ### EXCEPTION HANDLING

# %% [markdown]
# - `EXCEPTION`: It is nothing but it is an error.
#               - Whenever an execution is occurs it stops the program execution and it returns type of exception and followed by execution messsage.
#
# -`Types Of Error:` <br>
#     1. `Syntax Error (or) Compiletime Error` : The syntax error raises during the compilation time of the program, those errors are called as `Syntax Error`. <br>
#     `EX` : Intendationerror, Syntaxerror <br>
#     2. `Runtime Error` : The runtime error raises during Runtime of a program, those errors are called as `Runtime Error`  <br>
#                         - We cannot handle syntax error but we can handle the Runtime Errors by using Exception handling blocks(ie, try-except) <br>
#   `EXCEPTION HANDLING BLOCKS`: <br>
#                     `Syntax`: <br>
#                             try: <br>
#                                 # block code that might contains exception  <br>
#                             except: <br>
#                                 # exception handling block <br>
#                             else: [optional]<br>
#                                 # This block executes there is no exception raised in try block <br>
#                             finally: [optional] <br>
#                                 # This block always executes every exception raised or not. <br>
#
#
#      `EX` : KeyError, ValueError, Zero Division Error.  <br>
#     3. `Logical Error` :  <br>

# %%
# Syntax Errors:
print("hello)
# Out:
#   Cell In[9], line 2
#     print("hello)
#           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
print("hello"
# Out:
#   Cell In[6], line 1
#     print("hello"
#                  ^
# _IncompleteInputError: incomplete input

# %%
if 0==0:
print(0)
# Out:
#   Cell In[8], line 2
#     print(0)
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
# Runtime Error:
arr = [9,8,7,6,]
print(arr[4)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 3
#       1 # Runtime Error:
#       2 arr = [9,8,7,6,]
# ----> 3 print(arr[4])
#
# IndexError: list index out of range

# %%
a = (name, age, gender)

# %%
try:
    list = list[1,2,3]
    print(list[10])
    print("Hi")
except:
    print("something wrong in try block")
else: 
    print("no exception raisrd in try block")
finally:
    print("program done")
# Out:
# something wrong in try block
# program done

# %%
# try block with exception
try:
    list = list[1,2,3]
    print(list[10])
    print("Hi")
except:
    print("something wrong in try block")
else: 
    print("no exception raisrd in try block")
finally:
    print("program done")
# Out:
# something wrong in try block
# program done

# %%
# try block without exception
try:
    list = [1,2,3]
    print(list[2])
    print("Hi")
except:
    print("something wrong in try block")
else: 
    print("no exception raisrd in try block")
finally:
    print("program done")
# Out:
# 3
# Hi
# no exception raisrd in try block
# program done

# %%
# we cannot handle the syntax error
try:
    print("hello')
except:
    print("something wrong in try block")
else: 
    print("no exception raised in try block")
finally:
    print("program done")
# Out:
#   Cell In[22], line 3
#     print("hello')
#           ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
try:
    a = 10
    b = 0
    c = a/b
    print(c)
except Exception as E:
    print(f"something wrong in try block: {E}")
# Out:
# something wrong in try block: division by zero

# %%
try:
    a = 10
    b = a.append(0)
    c = a/b
    print(b)
except Exception as E:
    print(f"something wrong in try block: {E}")
# Out:
# something wrong in try block: 'int' object has no attribute 'append'

# %%
try:
    a = 10
    b = a.append(0)
    print(b)
except ZeroDivisionError as e:
    print(f"Zero division not possible: {e}")
except ValueError as e:
    print(f"Value Error raised in Try block: {e}")
          
#except Exception as e:
 #   print(f"something wrong in try block: {e}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 7
#       3     b = a.append(0)
#       4     print(b)
#       5 except ZeroDivisionError as e:
#       6     print(f"Zero division not possible: {e}")
# ----> 7 except ValueError as e:
#       8     print(f"Value Error raised in Try block: {e}")
#       9
#      10 #except Exception as e:
#
# AttributeError: 'int' object has no attribute 'append'

# %%
try:
    a = 10
    b = 0
    c = a/b
    print(c)
except ZeroDivisionError as e:
    print(f"Zero division not possible: {e}")
except ValueError as e:
    print(f"Value Error raised in Try block: {e}")
          
except Exception as e:
    print(f"something wrong in try block: {e}")
# Out:
# Zero division not possible: division by zero

# %%
# It executes the specific exception block when specified exception raised otherwise, it executes the Common except block
try:
    a = 10
    b = a.append(1)
    c = a/b
    print(c)
except ZeroDivisionError as e:
    print(f"Zero division not possible: {e}")
except ValueError as e:
    print(f"Value Error raised in Try block: {e}")
except Exception as e: # Common except block with Exception class
    print(f"something wrong in addition.add: {e}")
# Out:
# something wrong in addition.add: 'int' object has no attribute 'append'
