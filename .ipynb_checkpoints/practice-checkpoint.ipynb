# %%
units = int(input())
is_senior = input().strip().lower()
if units <= 100:
    bill = units * 1.5
elif units <= 200:
    bill = units * 2.5
elif units <= 500:
    bill = units*4
elif unit<=800:
    bill = units*6
else:
    bill = units*6*1.05
if is_senior:
    bill = bill * 0.90
    print(bill)
# Out:
#  450
#  yes
# 1620.0

# %%
# sum of digits in a string
s = input()
total = sum(int(ch) for ch in s if ch.isdigit())
print(total)
# Out:
#  abc123def456
# 21

# %%
# string palindrome
s = input().lower()
if s == s[::-1]:
    print("True")
else:
    print("False")
# Out:
#  madam
# True

# %%
credit_score = int(intput())
monthly_income = int(input())
liabilities = int(input())
if credit_scnore>=750:  
    print("eligible")   
    if credit_score<650:
        print("rejected")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 credit_score = int(intput())
#       2 monthly_income = int(input())
#       3 liabilities = int(input())
#       4 if credit_scnore>=750:
#
# NameError: name 'intput' is not defined

# %%
print(110)
# Out:
# 110

# %%
print(int(input())*55)
# Out:
#  2
# 110
