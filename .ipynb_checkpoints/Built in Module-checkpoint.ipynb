# %%
import math
import random
import os
import sys

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
import math 
print(math.ceil(4.25))  # It returns the upperbound integer value
print(math.floor(4.25)) # It returns the lowerbound integer value
print(math.factorial(5)) # It returns the factorial of a number
print(math.gcd(10, 6, 4)) # It returns the greatest common divisior
print(math.lcm(10, 6, 4)) # It returns the least common multiplier
print(math.pow(10,3)) # pow(a,b): It returns the float type of a raise to b
print(math.sqrt(12)) # It returns the square root of a number
print(math.log10(4)) # To find the logic10 values
# Out:
# 5
# 4
# 120
# 2
# 60
# 1000.0
# 3.4641016151377544
# 0.6020599913279624

# %%
import random
print(random.random()) # This function generates the random number between 0 to 1
print(random.randint(1,6)) # This function generates the random number between a range 
print(random.randint(1000,9999)) # 4 digit OTP generation
print(random.choice(['A',1,2,3,4,5,67,8,9,'J', 'Q', 'K'])) # This function returns random value from sequence
print(random.choices(['A',1,2,3,4,5,67,8,9,'J', 'Q', 'K'], k=13)) #
arr = ['A',1,2,3,4,5,67,8,9,'J', 'Q', 'K']
random.shuffle(arr)
print(arr)
# Out:
# 0.01423354259206755
# 3
# 6368
# 2
# [4, 4, 5, 2, 'Q', 9, 2, 9, 3, 'K', 67, 'J', 5]
# [67, 8, 4, 3, 9, 'Q', 5, 2, 1, 'K', 'J', 'A']

# %%
# who will reach top(100) in less steps
import random
count = rolls = 0
print("Welcome to the who will reach top in less steps game")
while True:
    input("To throw a dice, please click enter button")
    face_val = random.randint(1, 6)
    if count + face_val <=100:
        count += face_val
    rolls+=1
    if count == 100:
        print(f"You reached the top in {rolls} chances")
        break
    print(f"Your Dice value:{face_val}")
    print(f"Your at {count} position in {rolls} chances")
    print("*" * 100)
# Out:
# Welcome to the who will reach top in less steps game
# To throw a dice, please click enter button
# Your Dice value:5
# Your at 5 position in 1 chances
# ****************************************************************************************************
# To throw a dice, please click enter button
# Your Dice value:4
# Your at 9 position in 2 chances
# ****************************************************************************************************
# To throw a dice, please click enter button
# Your Dice value:3
# Your at 12 position in 3 chances
# ****************************************************************************************************
# To throw a dice, please click enter button
# Your Dice value:1
# Your at 13 position in 4 chances
# ****************************************************************************************************
# To throw a dice, please click enter button
# Your Dice value:4
# Your at 17 position in 5 chances
# ...

# %%
import os
print(os.getcwd()) # it returns the current working directiory
os.mkdir('test')
# Out:
# G:\python

# %%
import os
print(os.getcwd())# it returns the current working directiory
if not os.path.exists('test'):  # os.path.exists(path): it returns True if path exists  
    os.mkdir('test') # this functions create new empty directory
os.chdir('..')
os.chdir('modules')
print(os.getcwd())
# Out:
# G:\python\modules
# G:\python\modules

# %%
print(os.getcwd())
print(os.listdir("."))
os.chdir(".")
print(os.getcwd())
# Out:
# G:\python\modules
# ['addition.py', 'division.py', 'modulo_division.py', 'multiplication.py', 'small_calulator.py', 'square.py', 'squareroot.py', 'subtraction.py', 'test']
# G:\python\modules
