# %%
#define perrson class
class Student:
    school = "XYZ school" 
    def __init__(self, name, age):    # Initialization constuctor (Magic method)
        self.name = name   # Instance Attributes
        self.age = age      # Instance Attributes
        #print("This Student class __init__ method")
    def details(self):
        return f"My name is {self.name} and i am a {self.age} years old"
        
s1 = Student("Priya", 21)
s2 = Student("Rishi", 30)
print(s1)
print(s1.name)
print(s2.age)
print(s1.details())
print(s2.details())
print(s1.school)
print(s2.school)
# Out:
# <__main__.Student object at 0x0000016FCD08BA10>
# Priya
# 30
# My name is Priya and i am a 21 years old
# My name is Rishi and i am a 30 years old
# XYZ school
# XYZ school

# %%
# define 
#define perrson class
class Student:
    school = "XYZ school" 
    def __init__(self, name, age):    # Initialization constuctor (Magic method)
        self.name = name   # Instance Attributes
        self.age = age      # Instance Attributes
        #print("This Student class __init__ method")
    def details(self):
        return f"My name is {self.name} and i am a {self.age} years old"
        
s1 = Student("Priya", 21)
s2 = Student("Rishi", 30)
print(s1.name)
s1.name = "Pranathi"
print(s1.name)
print(s1.school)
s1.school = "ABC school"
print(s1.school, s2.school)
print(Student.school)
Student.schoolD = "ABC school"
print(s1.school, s2.school)
# Out:
# Priya
# Pranathi
# XYZ school
# ABC school XYZ school
# XYZ school
# ABC school XYZ school
